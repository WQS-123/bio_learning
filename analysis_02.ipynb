# %%
import pandas as pd

### CRISPR knockout screen across 1000+ cell lines

df_crispr = pd.read_csv('CRISPRGeneEffect.csv',index_col=0)

df_crispr
# Out:
#             A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# ACH-000001 -0.121964      0.042647  0.026102       -0.147614
# ACH-000004 -0.016484     -0.088500 -0.088198       -0.041225
# ACH-000005 -0.184847      0.003300  0.160881        0.086224
# ACH-000007 -0.071921     -0.113717  0.082872        0.099633
# ACH-000009 -0.019163     -0.134669  0.060323        0.076647
# ...              ...           ...       ...             ...
# ACH-002926 -0.107883     -0.101501  0.046677        0.096868
# ACH-002928 -0.287606     -0.179101 -0.135824       -0.046579
# ACH-003012 -0.145878     -0.004000  0.091933        0.191332
# ACH-003177 -0.038435     -0.055660  0.018989        0.117182
# ACH-003180 -0.007314     -0.212478  0.129900       -0.023112
#
#             A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# ACH-000001         -0.020425        0.184014      -0.076020    -0.097068
# ACH-000004         -0.028074       -0.157206       0.280101    -0.106904
# ACH-000005         -0.149315       -0.253837       0.167011    -0.101209
# ACH-000007         -0.008378       -0.022310       0.014416    -0.184977
# ACH-000009          0.078922       -0.100243       0.047559    -0.136988
# ...                      ...             ...            ...          ...
# ACH-002926         -0.118650       -0.065258      -0.064944    -0.175912
# ACH-002928         -0.249888       -0.097376       0.070385     0.049444
# ACH-003012         -0.065385       -0.134152       0.012353    -0.321012
# ACH-003177          0.063397        0.049993       0.175520    -0.085752
# ACH-003180         -0.068613        0.067406       0.003678    -0.312161
#
#             AACS (65985)  AADAC (13)  ...  ZWILCH (55055)  ZWINT (11130)  \
# ACH-000001      0.182759   -0.002365  ...       -0.120536       0.107286
# ACH-000004      0.178125    0.149760  ...       -0.192527      -0.324059
# ACH-000005     -0.129827    0.029143  ...       -0.312827      -0.338023
# ACH-000007     -0.173739    0.196363  ...       -0.334843      -0.355499
# ACH-000009      0.037759    0.093207  ...       -0.299593      -0.194427
# ...                  ...         ...  ...             ...            ...
# ACH-002926     -0.044707    0.126244  ...       -0.409541      -0.579376
# ACH-002928     -0.244937    0.058041  ...       -0.095328      -0.440452
# ACH-003012      0.001571    0.146177  ...       -0.280119      -0.662673
# ACH-003177      0.078435    0.089513  ...       -0.080700      -0.476797
# ACH-003180      0.009587    0.056658  ...       -0.038622      -0.667881
#
#             ZXDA (7789)  ZXDB (158586)  ZXDC (79364)  ZYG11A (440590)  \
# ACH-000001     0.166390       0.262275      0.163876        -0.249508
# ACH-000004     0.230377       0.087609      0.074897         0.054335
# ACH-000005    -0.039700      -0.055349     -0.000367        -0.205605
# ACH-000007    -0.014183       0.230944      0.044628        -0.081863
# ACH-000009    -0.027365       0.236591     -0.084224        -0.098271
# ...                 ...            ...           ...              ...
# ACH-002926     0.038706       0.338610     -0.174379        -0.040264
# ACH-002928     0.303500       0.097690      0.151790         0.039994
# ACH-003012    -0.180936       0.169997     -0.036326         0.158702
# ACH-003177    -0.158375      -0.008999     -0.030058        -0.103513
# ACH-003180    -0.090500       0.077756      0.055249         0.040616
#
#             ZYG11B (79699)  ZYX (7791)  ZZEF1 (23140)  ZZZ3 (26009)
# ACH-000001        0.053725    0.067986       0.136285     -0.438536
# ACH-000004       -0.330343    0.099067       0.274566      0.001871
# ACH-000005       -0.066032   -0.054518       0.035579     -0.150486
# ACH-000007       -0.390748   -0.036547      -0.273129     -0.382723
# ACH-000009       -0.510495    0.052938       0.018623     -0.258353
# ...                    ...         ...            ...           ...
# ACH-002926       -0.239763    0.065168      -0.144088     -0.334424
# ACH-002928        0.098240   -0.266654      -0.115108     -0.080421
# ACH-003012       -0.213281   -0.017884      -0.195395     -0.309021
# ACH-003177       -0.119234   -0.153744       0.032584     -0.536071
# ACH-003180       -0.378505   -0.143920      -0.039985     -0.439905
#
# [1178 rows x 17916 columns]

# %%
df_crispr.columns = [s[0:s.index('(')-1] for s in df_crispr.columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(3,2),dpi=300)
plt.rcParams["font.size"] = 10
plt.rcParams["font.family"] = "Helvetica"


ls1 = df_crispr['TADA3']
ls2 = df_crispr['SGF29']

plt.scatter(ls1,ls2,s=4)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.

# %%
saga_ls = ['ADA','ATXN7L1','ATXN7L2','ATXN7L3','KAT2A','SGF29','CCDC101','SUPT7L','TAF5L','TAF6L','SUPT20H',
           'TAF10','TAF12','TAF9L','SUPT3H','TADA2B','TADA3','USP22']

atac_ls = ['KAT14','KAT2A','MBIP','DR1','SGF29','TADA2A','TADA3','WDR5','YEATS2','ZZZ3','CSRP2BP']

combine_ls = list(set(saga_ls)|set(atac_ls))
print(combine_ls)
# Out:
# ['SUPT7L', 'TAF5L', 'SUPT3H', 'SGF29', 'TADA2B', 'CSRP2BP', 'KAT14', 'SUPT20H', 'YEATS2', 'ATXN7L3', 'CCDC101', 'ATXN7L1', 'KAT2A', 'TAF10', 'TADA3', 'TAF9L', 'ATXN7L2', 'MBIP', 'TAF12', 'DR1', 'ADA', 'TADA2A', 'TAF6L', 'WDR5', 'USP22', 'ZZZ3']

# %%
from scipy.stats import pearsonr

df_crispr_com = df_crispr.T.loc[[c for c in combine_ls if c in df_crispr.columns],:].dropna(how='any').T

cor_dic = {}
for i in df_crispr_com.columns:
    cor_ls = []
    for j in df_crispr_com.columns:
         cor_ls.append(pearsonr(df_crispr_com[i],df_crispr_com[j])[0])   
    cor_dic[i] = cor_ls
data = pd.DataFrame(cor_dic,columns=df_crispr_com.columns)
data.index = df_crispr_com.columns
print(data)
# Out:
#            SUPT7L     TAF5L    SUPT3H     SGF29    TADA2B     KAT14   SUPT20H  \
# SUPT7L   1.000000  0.659954  0.345020  0.454802  0.637861  0.029775  0.617625
# TAF5L    0.659954  1.000000  0.020366  0.676584  0.833400  0.043860  0.817845
# SUPT3H   0.345020  0.020366  1.000000 -0.008831 -0.005106  0.055406  0.017577
# SGF29    0.454802  0.676584 -0.008831  1.000000  0.692066  0.140683  0.632105
# TADA2B   0.637861  0.833400 -0.005106  0.692066  1.000000  0.038227  0.824790
# KAT14    0.029775  0.043860  0.055406  0.140683  0.038227  1.000000  0.039682
# SUPT20H  0.617625  0.817845  0.017577  0.632105  0.824790  0.039682  1.000000
# WDR5     0.078337 -0.009986  0.006994  ... -0.051921  0.028669 -0.053028
# USP22   -0.046087  0.295386  0.090088  ... -0.041609 -0.002785  0.225988
# ZZZ3     0.386014 -0.054998  0.028639  ...  0.039362  0.181258 -0.010532
#
#               DR1       ADA    TADA2A     TAF6L      WDR5     USP22      ZZZ3
# SUPT7L   0.140307 -0.004251 -0.147395  0.689208  0.081154  0.451579 -0.077454
# TAF5L    0.048578  0.015801 -0.148488  0.751014  0.097031  0.549528 -0.102624
# SUPT3H   0.141023 -0.040261  0.072425  0.120824  0.033821  0.012853  0.008962
# SGF29    0.066383  0.012361  0.004199  0.588190  0.104459  0.432399  0.011597
# TADA2B   0.066880 -0.005063 -0.186831  0.768624  0.093973  0.498659 -0.145285
# KAT14    0.183790 -0.003960  0.277826  0.007876  0.068626  0.083904  0.323760
# SUPT20H  0.065940  0.003636 -0.141976  0.752625  0.075385  0.533991 -0.109467
# YEATS2   0.144125  0.001631  0.357070 -0.129005  0.078337 -0.046087  0.386014
# ATXN7L3  0.059408  0.005086 -0.034186  0.193602 -0.009986  0.295386 -0.054998
# ATXN7L1  0.052482 -0.088963  0.028965  0.100866  0.006994  0.090088  0.028639
# KAT2A    0.030507 -0.020935  0.102500  0.392547  0.055188  0.260565  0.039545
# TAF10    0.092609 -0.016304 -0.047831  0.273673  0.106128  0.273282 -0.020747
# TADA3    0.189803  0.067834  0.033455  0.538619  0.131358  0.429150  0.124137
# ATXN7L2 -0.023917 -0.027442  0.081866 -0.023190 -0.051921 -0.041609  0.039362
# MBIP     0.078636 -0.022162  0.153904 -0.077748  0.028669 -0.002785  0.181258
# TAF12   -0.008860 -0.006016  0.011266  0.230396 -0.053028  0.225988 -0.010532
# DR1      1.000000  0.020859  0.171484  0.038352  0.014609  0.086454  0.205577
# ADA      0.020859  1.000000 -0.040504  0.014506 -0.033530 -0.042810 -0.014807
# TADA2A   0.171484 -0.040504  1.000000 -0.147708  0.010602 -0.030098  0.408997
# TAF6L    0.038352  0.014506 -0.147708  1.000000  0.021639  0.469439 -0.140849
# WDR5     0.014609 -0.033530  0.010602  0.021639  1.000000  0.039781  0.044573
# USP22    0.086454 -0.042810 -0.030098  0.469439  0.039781  1.000000 -0.028222
# ZZZ3     0.205577 -0.014807  0.408997 -0.140849  0.044573 -0.028222  1.000000
#
# [23 rows x 23 columns]

# %%
import networkx as nx
import numpy as np

np.random.seed(1027)

links = data.stack().reset_index()
links.columns = ['gene1','gene2','corr']

links_filtered=links.loc[(abs(links['corr']) > 0.2) & (links['gene1'] != links['gene2']) ]
#print links_filtered

plt.figure(figsize=(8,4),dpi=300)

G=nx.from_pandas_edgelist(links_filtered, 'gene1', 'gene2',['corr'])
color_list = []
for u,v in G.edges():
    color_list.append(G[u][v]['corr'])
    
#print color_list
pos = nx.spring_layout(G)

# nx.draw(G,pos,with_labels=True, node_color='orange', node_size=500, edge_color=color_list, edge_cmap=plt.cm.bwr, 
#         width=[10*abs(i) for i in color_list], font_size=6)

nx.draw(G, pos,with_labels=True, node_color='orange', node_size=600, edge_color='lightblue',
        width=3.0,font_size=6)

plt.show()
